# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !bash read-line.txt test-after.txt
# Out:
# Name read from file - d0f7d20e23ad2073.jpg
# Name read from file - d0f7d20e23ad2073.txt
# Name read from file - d0fcc62de6424a6c.jpg
# Name read from file - d0fcc62de6424a6c.txt
# Name read from file - d101b7277d392877.jpg
# Name read from file - d101b7277d392877.txt
# Name read from file - d103c716cf36f6fd.jpg
# Name read from file - d103c716cf36f6fd.txt
# Name read from file - d10ca1d25bdd5013.jpg
# Name read from file - d10ca1d25bdd5013.txt
# Name read from file - d1151ed55544cd56.jpg
# Name read from file - d1151ed55544cd56.txt
# Name read from file - d11dfa5f1706b8a8.jpg
# Name read from file - d11dfa5f1706b8a8.txt
# Name read from file - d14b09313e1cb310.jpg
# Name read from file - d14b09313e1cb310.txt
# Name read from file - d1526e0060a517c1.jpg
# Name read from file - d1526e0060a517c1.txt
# Name read from file - d1557084a39db05c.jpg
# Name read from file - d1557084a39db05c.txt
# Name read from file - d15e26bc2172f5f9.jpg
# Name read from file - d15e26bc2172f5f9.txt
# ...

# %%
#!cp /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/laptop-obj-1.zip ./
#!cp /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/laptop-test-1.zip ./
# !cp /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-all-1.zip ./
# !cp /content/gdrive/MyDrive/Tugas/Pra\ TA/split-folder-dataset_v2.py ./

# %%
#!unzip laptop-obj-1.zip -d data
#!unzip laptop-test-1.zip -d data
# !unzip eye-glasses-goggles-all-1 -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/Label/e11e8255eafd8735.txt
#   inflating: data/Label/24b549c416fef4e4.txt
#  extracting: data/Label/fc42e32586b5a129.txt
#   inflating: data/Label/11a52c0eeebf67f7.txt
#   inflating: data/Label/62a89a49fe317964.txt
#   inflating: data/Label/f52c9cdab00211cc.txt
#   inflating: data/Label/fd55499a25c2cde0.txt
#   inflating: data/Label/eb9e89b88cfd3092.txt
#   inflating: data/Label/572b2a50397d61cd.txt
#   inflating: data/Label/37159a1c0d3a6695.txt
#   inflating: data/Label/ebd57b137495c99a.txt
#  extracting: data/Label/5b5e79bf7aafbf6b.txt
#  extracting: data/Label/f7c3c8e280292408.txt
#   inflating: data/Label/f9542f8bbd94f8e6.txt
#   inflating: data/Label/c1bc5bc88776beae.txt
#   inflating: data/Label/90908b61d6f70bc5.txt
#   inflating: data/Label/c7c7f04121beeb01.txt
#  extracting: data/Label/c0186612f7994f9f.txt
#   inflating: data/Label/46e80527b1852c52.txt
#   inflating: data/Label/c4191784be1069b5.txt
# ...

# %%
#!rm -rf /content/data/test1.txt
#!rm -rf /content/data/test2.txt
#!rm -rf /content/data/test3.txt
# !rm -rf /content/data/Label

# %%
# count files
# %cd /content/data
# !ls | wc -l
# %cd /content/
# Out:
# /content/data
# 18597
# /content

# %%
print(18596/2)
print(3000+2811+2703+200+192+166+80+77+69)
# Out:
# 9298.0
# 9298

# %%
# !python3 split-folder-dataset_v2.py
# Out:
# source path :  /content/data/
# destination path :  /content/data-2
#
# sum of your files :  18596
# sum of your images :  9298
#
# your division
# train_div :  0.68
# val_div :  0.17
# test_div :  0.15
# percentage of dataset division 1.0
#
#
# Image Files
#
# sumImages :  9298
# count_train :  6322.64
# count_val :  1580.66
# count_test :  1394.7
#
# Image with Annotations
#
# lenList :  18596
# count_train :  12645.28
# count_val :  3161.32
# count_test :  2789.4
#
# Mod
#
# count_train :  6323
# count_val :  1580
# count_test :  1394
# sum_mod :  9297
#
# Update Mod
#
# count_train :  6324
# count_val :  1580
# count_test :  1394
# sum_mod :  9298
#
# Mod with Annotation
#
# count_train :  12648
# count_val :  3160
# count_test :  2788
# sum_mod :  18596
#
# Mod len
#
# len_train :  12648
# len_val :  15808
# len_test :  18596
# ...

# %%
# count files
# %cd /content/data-2/train/
# !ls | wc -l
# %cd /content/data-2/val/
# !ls | wc -l
# %cd /content/data-2/test/
# !ls | wc -l
# %cd /content/
# Out:
# /content/data-2/train
# 12648
# /content/data-2/val
# 3160
# /content/data-2/test
# 2788
# /content

# %%
# validate
print("train : "+str(12648/2))
print("val : "+str(3160/2))
print("test : "+str(2788/2))
# Out:
# train : 6324.0
# val : 1580.0
# test : 1394.0

# %%
# %cd /content/data-2/train/
# !zip -r /content/eye-glasses-goggles-obj-1.zip *
# %cd /content/data-2/val/
# !zip -r /content/eye-glasses-goggles-test-1.zip *
# %cd /content/data-2/test/
# !zip -r /content/eye-glasses-goggles-test-after-1.zip *
# %cd /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: b25da2a2538cbcf2.jpg (deflated 0%)
#   adding: b25da2a2538cbcf2.txt (deflated 44%)
#   adding: b25f07f2c412a389.jpg (deflated 0%)
#   adding: b25f07f2c412a389.txt (deflated 32%)
#   adding: b25f9f14482e473d.jpg (deflated 0%)
#   adding: b25f9f14482e473d.txt (deflated 51%)
#   adding: b261812309e99650.jpg (deflated 0%)
#   adding: b261812309e99650.txt (deflated 35%)
#   adding: b267cd2afa892483.jpg (deflated 0%)
#   adding: b267cd2afa892483.txt (deflated 32%)
#   adding: b27e7800a676e7be.jpg (deflated 1%)
#   adding: b27e7800a676e7be.txt (deflated 45%)
#   adding: b28c05ab6da060e1.jpg (deflated 0%)
#   adding: b28c05ab6da060e1.txt (deflated 24%)
#   adding: b28ddb44cabfe5c6.jpg (deflated 7%)
#   adding: b28ddb44cabfe5c6.txt (deflated 49%)
#   adding: b28ec147c56b8027.jpg (deflated 2%)
#   adding: b28ec147c56b8027.txt (deflated 22%)
#   adding: b290854afc4ca5df.jpg (deflated 0%)
# ...

# %%
# copy to google drive
# !cp /content/eye-glasses-goggles-obj-1.zip /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/
# !cp /content/eye-glasses-goggles-test-1.zip /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/
# !cp /content/eye-glasses-goggles-test-after-1.zip /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/

# %% [markdown]
# ## Tracing

# %%
# !rm -rf /content/data-2

# %%
import os, os.path, shutil, math

# count files
#dir = '/content/data-2/' # your path
#sum_files = len([name for name in os.listdir(dir) if os.path.isfile(os.path.join(dir, name))])
#print(sum_files)

# create directories
path = "/content/data-3/train" # your path
os.makedirs(path)
path = "/content/data-3/val" # your path
os.makedirs(path)
path = "/content/data-3/test" # your path
os.makedirs(path)

# save all of filenames in list, then sort it asc
myList = os.listdir(DIR)
myList.sort()
print(len(myList))
# Out:
# 11504
# 11504

# %%
# percentage of dataset division for train_set, val_set, test_set
train_div = 0.68
val_div = 0.17
test_div = 0.15

print("percentage of dataset division",train_div+val_div+test_div,"\n")

if (train_div+val_div+test_div != 1.0):
  raise ValueError("Must be 1.0")

# sum of files in each set
lenList = 11504
#lenList = len(myList)
count_train = lenList*train_div
count_val = lenList*val_div
count_test = lenList*test_div

print("lenList : ",lenList)
print("count_train : ",count_train)
print("count_val : ",count_val)
print("count_test : ",count_test)

print("\nMod\n")

mod_count_train = math.ceil(count_train)
mod_count_val = math.floor(count_val)
mod_count_test = math.floor(count_test)
sum_mod = mod_count_train+mod_count_val+mod_count_test

print("count_train : ",mod_count_train)
print("count_val : ",mod_count_val)
print("count_test : ",mod_count_test)
print("sum_mod : ",sum_mod)

print("\nUpdate Mod\n")

if(sum_mod<lenList):
  mod_count_train += lenList - sum_mod
  sum_mod = mod_count_train+mod_count_val+mod_count_test

print("count_train : ",mod_count_train)
print("count_val : ",mod_count_val)
print("count_test : ",mod_count_test)
print("sum_mod : ",sum_mod)

len_train = mod_count_train
len_val = len_train + mod_count_val
len_test = len_val + mod_count_test

print("\nMod len\n")

print("len_train : ",len_train)
print("len_val : ",len_val)
print("len_test : ",len_test)
# Out:
# percentage of dataset division 1.0
#
# lenList :  11504
# count_train :  7822.72
# count_val :  1955.68
# count_test :  1725.6
#
# Mod
#
# count_train :  7823
# count_val :  1955
# count_test :  1725
# sum_mod :  11503
#
# Update Mod
#
# count_train :  7824
# count_val :  1955
# count_test :  1725
# sum_mod :  11504
#
# Mod len
#
# len_train :  7824
# len_val :  9779
# len_test :  11504

# %%
# moving files
list_train = []
list_val = []
list_test = [] # ln 30

for i in range(len_train):
	list_train.append(myList[i])

for i in range(len_train,len_val):
	list_val.append(myList[i])

for i in range(len_val,len_test):
	list_test.append(myList[i])

print(list_train,"\n sum :",len(list_train))
print(list_val,"\n sum :",len(list_val))
print(list_test,"\n sum :",len(list_test))

for f in list_train:
  shutil.move('/content/data-2/'+f, '/content/data-3/train') # your path

for f in list_val:
  shutil.move('/content/data-2/'+f, '/content/data-3/val') # your path

for f in list_test:
  shutil.move('/content/data-2/'+f, '/content/data-3/test') # your path
# Out:
# ['000060e3121c7305.jpg', '000060e3121c7305.txt', '00022a6311159428.jpg', '00022a6311159428.txt', '0002af997ecdfcf4.jpg', '0002af997ecdfcf4.txt', '000396ae942e8778.jpg', '000396ae942e8778.txt', '00048edce2a37368.jpg', '00048edce2a37368.txt', '0005d2c43b82a3dc.jpg', '0005d2c43b82a3dc.txt', '000776501b89bf47.jpg', '000776501b89bf47.txt', '0008c0909fb45c79.jpg', '0008c0909fb45c79.txt', '0009debd0e9d1fca.jpg', '0009debd0e9d1fca.txt', '000c9121b17ee0ff.jpg', '000c9121b17ee0ff.txt', '000cd862a3c97051.jpg', '000cd862a3c97051.txt', '000e1dd786c8e433.jpg', '000e1dd786c8e433.txt', '000e3e4f5c6c454d.jpg', '000e3e4f5c6c454d.txt', '00103cd22a757365.jpg', '00103cd22a757365.txt', '00106a172812b3b0.jpg', '00106a172812b3b0.txt', '00107c014500a8cb.jpg', '00107c014500a8cb.txt', '00112c426578e854.jpg', '00112c426578e854.txt', '0015c6105c9e7a3a.jpg', '0015c6105c9e7a3a.txt', '0016730ee38621fd.jpg', '0016730ee38621fd.txt', '00185eed7ee580c2.jpg', '00185eed7ee580c2.txt', '001a064f84f98c59.jpg', '001a064f84f9
# ...

# %%
"""
Fix Dataset TA
count_train :  7824
count_val :  1955
count_test :  1725
sum_mod :  11504
"""

print(7824/2)
print(1956/2)
print(1724/2)

print(3912+978+862)
# Out:
# 3912.0
# 978.0
# 862.0
# 5752

# %%
"""
train : 6903
val : 2301
test : 2300
"""

print(11504*0.6)
print(11504*0.2)
print(11504*0.2)
print(6903+2301+2300)

print(11504/2)
print(5752*0.6)
print(5752*0.2)
print(5752*0.2)

print(3451.2*2)
print(1150.4*2)
print(1150.4*2)
print(6902.4+2300.8+2300.8)
# Out:
# 6902.4
# 2300.8
# 2300.8
# 11504
# 5752.0
# 3451.2
# 1150.4
# 1150.4
# 6902.4
# 2300.8
# 2300.8
# 11504.0

# %%
# random list
random = [(2, 2), (3, 4), (4, 1), (1, 3)]
random2 = ["00.t","01.j","11.j","01.t","11.t","00.j","12.j","22.t","12.t","22.j"]

# sort list with key
random2.sort()

# print list
print('Sorted list:', random2) # ln 10

temp = random2
print('Temp list:', temp)

sub1 = 0.6
sub2 = 0.2
sub3 = 0.2

lenStr = len(random2)
len1 = lenStr*sub1 # ln 20
len2 = len1 + lenStr*sub2
len3 = len2 + lenStr*sub3
print("lenStr : ",lenStr)
print("len1 : ",len1)
print("len2 : ",len2)
print("len3 : ",len3)

list1 = []
list2 = []
list3 = [] # ln 30

for i in range(int(len1)):
	list1.append(temp[i])

for i in range(int(len1),int(len2)):
	list2.append(temp[i])

for i in range(int(len2),int(len3)):
	list3.append(temp[i])

print(list1," -> ",len(list1))
print(list2," -> ",len(list2))
print(list3," -> ",len(list3))
# Out:
# Sorted list: ['00.j', '00.t', '01.j', '01.t', '11.j', '11.t']
# ['00.j', '00.t', '01.j']
# ['01.t', '11.j', '11.t']
