# %%
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 444, done.
# remote: Total 444 (delta 0), reused 0 (delta 0), pack-reused 444
# Receiving objects: 100% (444/444), 34.09 MiB | 29.63 MiB/s, done.
# Resolving deltas: 100% (157/157), done.

# %%
import random
training = range(31)
mylist = ["apple", "banana", "cherry"]
random.shuffle(mylist)

print(mylist)
print(training)
# Out:
# ['apple', 'banana', 'cherry']
# range(0, 31)

# %%
import itertools
import random
training = [1,2,3,4,5,6,7,8,9]

# copy training to preserve the order of the original dataset
this_round = training

# permute the elements
random.shuffle(this_round)

# separate into training and test
# training_this_round = this_round[:5]
training_this_round = set(itertools.islice(this_round, 5))
testing_this_round = this_round[5:10]

print (training_this_round)
print(testing_this_round)
# Out:
# {1, 4, 5, 7, 9}
# [3, 2, 8, 6]

# %%
# !pip3 install -r OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.7 MB 4.5 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 27.9 MB/s
# ...
#      |████████████████████████████████| 547 kB 53.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 74.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#drive.flush_and_unmount()
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/
# !python3 OIDv4_ToolKit/main.py downloader --classes "Human eye" "Glasses" "Goggles" --type_csv validation --limit 10 --multiclass 1
# Out:
# /content
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Human eye', 'Glasses', 'Goggles'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 34897 KB/s, 0 seconds passed
# ...

# %%
# %cd /content/
# !python3 OIDv4_ToolKit/main.py downloader --classes "Human eye" "Glasses" "Goggles" --type_csv train --limit 3000 --multiclass 1
# Out:
# /content
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Human eye', 'Glasses', 'Goggles'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 33403 KB/s, 0 seconds passed
# ...

# %%
# !python3 OIDv4_ToolKit/main.py downloader --classes "Human eye" "Glasses" "Goggles" --type_csv test --limit 200 --multiclass 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Human eye', 'Glasses', 'Goggles'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 34951 KB/s, 0 seconds passed
# ...

# %%
#%cd 
# !python3 OIDv4_ToolKit/main.py downloader --classes "Human eye" "Glasses" "Goggles" --type_csv validation --limit 80 --multiclass 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Human eye', 'Glasses', 'Goggles'] together.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 16 MB, 40607 KB/s, 0 seconds passed
# ...

# %%
#!rm -rf /content/OID/Dataset/test/*
# !rm -rf /content/OID/Dataset/train/*
#!rm -rf /content/OID/Dataset/validation/*

# %%
# !mkdir -p /content/OID/Dataset/train/Masker
# !mkdir -p /content/OID/Dataset/validation/Masker
# !mkdir -p /content/OID/Dataset/test/Masker
# !mkdir -p /content/OID/Dataset/train/Masker/Label
# !mkdir -p /content/OID/Dataset/validation/Masker/Label
# !mkdir -p /content/OID/Dataset/test/Masker/Label
#!cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Laptop/* /content/OID/Dataset/train/Laptop/
#!mv /content/OID/Dataset/train/* /content/OID/Dataset/validation/Laptop/

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('/content/OID/Dataset/train/Laptop/000060e3121c7305.jpg')

# %%
#!mv -v /content/OID/Dataset/Human\ eye_Glasses_Goggles /content/OID/Dataset/train/

#!mkdir -p /content/OID/train-temp/
#!mkdir -p /content/OID/validation-temp/
# !mkdir -p /content/OID/test-temp/

#!mv -v /content/OID/Dataset/Golf\ ball /content/OID/Dataset/train-temp
#!mv -v /content/OID/Dataset/validation/Golf\ ball /content/OID/validation-temp
# !mv -v /content/OID/Dataset/test/Human\ eye_Glasses_Goggles /content/OID/test-temp

#!mv -v /content/OID/Dataset/Tennis\ ball /content/OID/Dataset/train-temp
#!mv -v /content/OID/Dataset/validation/Tennis\ ball /content/OID/validation-temp
#!mv -v /content/OID/Dataset/test/Tennis\ ball /content/OID/test-temp

#!mv -v /content/OID/train-temp/Tennis\ ball /content/OID/Dataset/train/
#!mv -v /content/OID/validation-temp/Tennis\ ball /content/OID/Dataset/validation/
#!mv -v /content/OID/test-temp/Tennis\ ball /content/OID/Dataset/test/
# Out:
# mv: cannot stat '/content/OID/Dataset/Human eye_Glasses_Goggles': No such file or directory
# renamed '/content/OID/Dataset/test/Human eye_Glasses_Goggles' -> '/content/OID/test-temp/Human eye_Glasses_Goggles'

# %%
# edit to the absolute path for classes.txt
# !python3 /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Traceback (most recent call last):
#   File "/content/OIDv4_ToolKit/convert_annotations.py", line 29, in <module>
#     with open("classes.txt", "r") as myFile:
# FileNotFoundError: [Errno 2] No such file or directory: 'classes.txt'

# %%
#!cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Human\ eye_Glasses_Goggles /content/OID/Dataset/train/
# !cp -av /content/OID/Dataset/train/* /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/
#!cp -av /content/OID/Dataset/test/* /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/
#!cp -av /content/OID/Dataset/validation/* /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test/
# Out:
# Streaming output truncated to the last 5000 lines.
# '/content/OID/Dataset/train/Human eye_Glasses_Goggles/bb5c9385e4671457.txt' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles/bb5c9385e4671457.txt'
# '/content/OID/Dataset/train/Human eye_Glasses_Goggles/00a5afdbd8449e5a.txt' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles/00a5afdbd8449e5a.txt'
# '/content/OID/Dataset/train/Human eye_Glasses_Goggles/8d48eb7581ad4466.txt' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles/8d48eb7581ad4466.txt'
# '/content/OID/Dataset/train/Human eye_Glasses_Goggles/b9a14f9e38630112.txt' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles/b9a14f9e38630112.txt'
# '/content/OID/Dataset/train/Human eye_Glasses_Goggles/f10c85a32532cae6.txt' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles/f10c85a32532cae6.txt'
# ...

# %%
# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Human\ eye_Glasses_Goggles
# !ls | wc -l
# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test/Human\ eye_Glasses_Goggles
# !ls | wc -l
# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/Human\ eye_Glasses_Goggles
# !ls | wc -l
#!ls -l *.txt | wc -l
#%cd /content/OID/Dataset/validation/Human\ eye_Glasses_Goggles
#!ls | wc -l
#%cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test/Laptop/
#!ls | wc -l
#%cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/Laptop/
#!ls | wc -l
# %cd /content/

# %%
#/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/obj/Human eye_Glasses_Goggles
#34059
print(8514*2)
print((3000+2811+2703)*2)
print(558*2)
print((200+192+166)*2)
print(226*2)
print((80+77+69)*2)
# Out:
# 17028
# 17028
# 1116
# 1116
# 452
# 452

# %%
#!rm -rf /content/OID/Dataset/train/wall\ clock
#!cp -av /content/OIDv4_ToolKit/classes.txt /content/OID/
# !cp -av /content/OID/classes.txt /content/OIDv4_ToolKit/
# Out:
# '/content/OID/classes.txt' -> '/content/OIDv4_ToolKit/classes.txt'
