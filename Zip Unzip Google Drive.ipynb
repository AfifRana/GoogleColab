# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# 000000000089.jpg  000000146439.txt  000000290774.jpg  000000438103.txt
# 000000000089.txt  000000146481.jpg  000000290774.txt  000000438294.jpg
# 000000000127.jpg  000000146481.txt  000000291349.jpg  000000438294.txt
# 000000000127.txt  000000146568.jpg  000000291349.txt  000000438314.jpg
# 000000000328.jpg  000000146568.txt  000000291438.jpg  000000438314.txt
# 000000000328.txt  000000146620.jpg  000000291438.txt  000000438453.jpg
# 000000000384.jpg  000000146620.txt  000000291541.jpg  000000438453.txt
# 000000000384.txt  000000147042.jpg  000000291541.txt  000000438497.jpg
# 000000000446.jpg  000000147042.txt  000000291816.jpg  000000438497.txt
# 000000000446.txt  000000147058.jpg  000000291816.txt  000000438762.jpg
# 000000000643.jpg  000000147058.txt  000000291830.jpg  000000438762.txt
# 000000000643.txt  000000147142.jpg  000000291830.txt  000000438899.jpg
# 000000000711.jpg  000000147142.txt  000000291839.jpg  000000438899.txt
# ...

# %%
# copy zip to colab
# !cp /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-all-1.zip ./

# %%
# zip folder or file in drive to drive
# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/Laptop/
#!zip -r /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/laptop-test-1.zip *
# %cd /content/
# Out:
# [Errno 2] No such file or directory: '/content/data/obj/'
# /content
#
#
# zip error: Interrupted (aborting)
# [Errno 2] No such file or directory: '/content/data/test'
# /content
#
#
# zip error: Interrupted (aborting)
# [Errno 2] No such file or directory: '/content/data/test-2'
# /content
#
#
# zip error: Interrupted (aborting)
# /content

# %%
# zip folder or file in colab to drive
#%cd /content/data/all/
#!zip -r /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/ball-all-1.zip *
# %cd /content/data/obj/
# !zip -r /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-obj-2.zip *
# %cd /content/data/test
# !zip -r /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-test-2.zip *
# %cd /content/data/test-2
# !zip -r /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-test-after-2.zip *
# %cd /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: a395f92f523e1093.txt (deflated 33%)
#   adding: a3a4921d6adb83fe.jpg (deflated 1%)
#   adding: a3a4921d6adb83fe.txt (deflated 59%)
#   adding: a41a887395a367cd.jpg (deflated 0%)
#   adding: a41a887395a367cd.txt (deflated 24%)
#   adding: a4246cd524e7de4c.jpg (deflated 0%)
#   adding: a4246cd524e7de4c.txt (deflated 40%)
#   adding: a46ca1c464084bea.jpg (deflated 0%)
#   adding: a46ca1c464084bea.txt (deflated 29%)
#   adding: a472273c95af4c72.jpg (deflated 0%)
#   adding: a472273c95af4c72.txt (deflated 31%)
#   adding: a4c044f2da9bb48d.jpg (deflated 0%)
#   adding: a4c044f2da9bb48d.txt (deflated 44%)
#   adding: a4c1a64effe5e81b.jpg (deflated 0%)
#   adding: a4c1a64effe5e81b.txt (deflated 31%)
#   adding: a4d7d77e023a9ac3.jpg (deflated 1%)
#   adding: a4d7d77e023a9ac3.txt (deflated 33%)
#   adding: a4f3454b565f722f.jpg (deflated 1%)
#   adding: a4f3454b565f722f.txt (deflated 47%)
# ...

# %%
# zip folder or file to colab storage

# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Human\ eye_Glasses_Goggles
# !zip -r /content/eye-glasses-goggles-all-1.zip *

# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test/Human\ eye_Glasses_Goggles
# !zip -r /content/eye-glasses-goggles-all-1.zip *

# %cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/Human\ eye_Glasses_Goggles
# !zip -r /content/eye-glasses-goggles-all-1.zip *

# %cd /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: Label/f52c9cdab00211cc.txt (deflated 19%)
#   adding: Label/fd55499a25c2cde0.txt (deflated 14%)
#   adding: Label/eb9e89b88cfd3092.txt (deflated 13%)
#   adding: Label/572b2a50397d61cd.txt (deflated 21%)
#   adding: Label/37159a1c0d3a6695.txt (deflated 25%)
#   adding: Label/ebd57b137495c99a.txt (deflated 15%)
#   adding: Label/5b5e79bf7aafbf6b.txt (stored 0%)
#   adding: Label/f7c3c8e280292408.txt (stored 0%)
#   adding: Label/f9542f8bbd94f8e6.txt (deflated 6%)
#   adding: Label/c1bc5bc88776beae.txt (deflated 32%)
#   adding: Label/90908b61d6f70bc5.txt (deflated 13%)
#   adding: Label/c7c7f04121beeb01.txt (deflated 11%)
#   adding: Label/c0186612f7994f9f.txt (stored 0%)
#   adding: Label/46e80527b1852c52.txt (deflated 10%)
#   adding: Label/c4191784be1069b5.txt (deflated 13%)
#   adding: Label/00b08c8735adaa79.txt (deflated 12%)
#   adding: Label/f6198e5b1f3a28ea.txt (deflated 34%)
# ...

# %%
# copy zip file to colab storage
#%cd /content/
#!cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/ball-all-1.zip /content/
# !cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-obj-1.zip /content/
# !cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-test-1.zip /content/
# !cp -av /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/eye-glasses-goggles-test-after-1.zip /content/
#!cp -av /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/coco_book/book-obj-4.zip /content/
# Out:
# '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/eye-glasses-goggles-obj-1.zip' -> '/content/eye-glasses-goggles-obj-1.zip'
# '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/eye-glasses-goggles-test-1.zip' -> '/content/eye-glasses-goggles-test-1.zip'
# '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/eye-glasses-goggles-test-after-1.zip' -> '/content/eye-glasses-goggles-test-after-1.zip'

# %%
# unzip file to colab folder
# %cd /content/
# !mkdir -p data
# !mkdir -p data/obj
# !mkdir -p data/test
# !mkdir -p data/test-2
#!rm -rf data/all/*
#!rm -rf data/obj/*
#!rm -rf data/test/*
#!rm -rf data/test-2/*
# !unzip eye-glasses-goggles-all-1.zip -d data/all
#!unzip eye-glasses-goggles-obj-1.zip -d data/obj
#!unzip eye-glasses-goggles-test-1.zip -d data/test
#!unzip eye-glasses-goggles-test-after-1.zip -d data/test-2
#!mv /content/darknet/data/obj/content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Book/* /content/darknet/data/obj/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/all/Label/e11e8255eafd8735.txt
#   inflating: data/all/Label/24b549c416fef4e4.txt
#  extracting: data/all/Label/fc42e32586b5a129.txt
#   inflating: data/all/Label/11a52c0eeebf67f7.txt
#   inflating: data/all/Label/62a89a49fe317964.txt
#   inflating: data/all/Label/f52c9cdab00211cc.txt
#   inflating: data/all/Label/fd55499a25c2cde0.txt
#   inflating: data/all/Label/eb9e89b88cfd3092.txt
#   inflating: data/all/Label/572b2a50397d61cd.txt
#   inflating: data/all/Label/37159a1c0d3a6695.txt
#   inflating: data/all/Label/ebd57b137495c99a.txt
#  extracting: data/all/Label/5b5e79bf7aafbf6b.txt
#  extracting: data/all/Label/f7c3c8e280292408.txt
#   inflating: data/all/Label/f9542f8bbd94f8e6.txt
#   inflating: data/all/Label/c1bc5bc88776beae.txt
#   inflating: data/all/Label/90908b61d6f70bc5.txt
#   inflating: data/all/Label/c7c7f04121beeb01.txt
#  extracting: data/all/Label/c0186612f7994f9f.txt
# ...

# %%
# unzip in google drive folder
#!unzip /content/gdrive/MyDrive/Tugas/COCO-2/2017_zips/annotations_trainval2017.zip -d /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/annotations_trainval2017
# !unzip /content/gdrive/MyDrive/Tugas/COCO-2/2017_zips/stuff_annotations_trainval2017.zip -d /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/stuff_annotations_trainval2017
# !unzip /content/gdrive/MyDrive/Tugas/COCO-2/2017_zips/val2017.zip -d /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/val2017
# !unzip /content/gdrive/MyDrive/Tugas/COCO-2/2017_zips/train2017.zip -d /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000259556.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000381931.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000569592.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000229396.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000488990.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000348684.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000234031.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000563584.jpg
#  extracting: /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/train2017/train2017/000000276069.jpg
# ...

# %%
# copy zip file to drive
# !cp -v /content/eye-glasses-goggles-all-1.zip /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/
# Out:
# '/content/eye-glasses-goggles-all-1.zip' -> '/content/gdrive/MyDrive/Tugas/Pra TA/Dataset TA/eye-glasses-goggles-all-1.zip'

# %%
# save list of files in directory to a file
# %cd /content/data/obj/
# !ls > /content/obj.txt
# %cd /content/data/test/
# !ls > /content/test.txt
# %cd /content/data/test-2/
# !ls > /content/test-after.txt
# %cd /content/
# Out:
# /content/data/obj
# /content/data/test
# /content/data/test-2
# /content

# %%
# !bash read-line.txt test-after-mod.txt
# Out:
# b881b8d270fd4275.jpg and b881b8d270fd4275.txt
# 'data/all/b881b8d270fd4275.jpg' -> '/content/data/test-2/b881b8d270fd4275.jpg'
# 'data/all/b881b8d270fd4275.txt' -> '/content/data/test-2/b881b8d270fd4275.txt'
# b89fa3a2c87e496e.jpg and b89fa3a2c87e496e.txt
# 'data/all/b89fa3a2c87e496e.jpg' -> '/content/data/test-2/b89fa3a2c87e496e.jpg'
# 'data/all/b89fa3a2c87e496e.txt' -> '/content/data/test-2/b89fa3a2c87e496e.txt'
# b8a217469b921998.jpg and b8a217469b921998.txt
# 'data/all/b8a217469b921998.jpg' -> '/content/data/test-2/b8a217469b921998.jpg'
# 'data/all/b8a217469b921998.txt' -> '/content/data/test-2/b8a217469b921998.txt'
# b8a2a0c0c215be76.jpg and b8a2a0c0c215be76.txt
# 'data/all/b8a2a0c0c215be76.jpg' -> '/content/data/test-2/b8a2a0c0c215be76.jpg'
# 'data/all/b8a2a0c0c215be76.txt' -> '/content/data/test-2/b8a2a0c0c215be76.txt'
# b8b10f09233c2672.jpg and b8b10f09233c2672.txt
# 'data/all/b8b10f09233c2672.jpg' -> '/content/data/test-2/b8b10f09233c2672.jpg'
# ...

# %%
# count files
#%cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/obj/Human\ eye_Glasses_Goggles
#!ls | wc -l

#%cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test/Human\ eye_Glasses_Goggles
#!ls | wc -l

#%cd /content/gdrive/MyDrive/Tugas/Pra\ TA/Dataset\ TA/test-2-oid/Human\ eye_Glasses_Goggles
#!ls | wc -l

# %cd /content/gdrive/MyDrive/Tugas/COCO-2/2017_2/coco_book/val/
# %cd /content/data/all/
# !ls | wc -l
# %cd /content/data/obj/
# !ls | wc -l
# %cd /content/data/test/
# !ls | wc -l
# %cd /content/data/test-2/
# !ls | wc -l
# %cd /content/
# Out:
# /content/data/all
# 18596
# /content/data/obj
# 10222
# /content/data/test
# 2556
# /content/data/test-2
# 2252
# /content

# %%
print(17029+452+1116)
#print((6000+5620+5406+200+189+158+80+76+62)*2)
#print(18596/2)
#print(6000+5620+5406)
#print((34058/2)-(6000+5620+5406))
# Out:
# 18597
